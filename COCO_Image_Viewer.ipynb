# %% [markdown]
# # COCO Image Viewer
# This notebook will allow you to view details about a COCO dataset and preview segmentations on annotated images.
# Learn more about it at: http://cocodataset.org/

# %%
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# %%
# Load the dataset json
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = ['blue', 'purple', 'red', 'green', 'orange', 'salmon', 'pink', 'gold',
                       'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                       'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                       'magenta', 'sienna', 'maroon']

        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()

        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()

    def display_info(self):
        print('Dataset Info:')
        print('=============')
        if self.info is None:
            return
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))

        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

    def display_licenses(self):
        print('Licenses:')
        print('=========')

        if self.licenses is None:
            return
        requirements = [['id', int],
                        ['url', str],
                        ['name', str]]
        for license in self.licenses:
            for key, item in license.items():
                print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(
                        req, str(req_type)))
            print('')
        print('')

    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(
                    cat_id, self.categories[cat_id]['name']))
            print('')

    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))

        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))

        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))

        else:
            # image_path = os.path.join(self.image_dir, image['file_name'])
            image_path = "{}/{}".format(self.image_dir, image['file_name'])
            image = PILImage.open(image_path)

        # Calculate the size and adjusted display size
        max_width = 600
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height

        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        bbox_categories = {}
        print('  segmentations ({}):'.format(
            len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(
                            trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height)
                                      * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})

                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1  # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(
                                    full_lines_to_insert * adjusted_ratio)
                                rle_list.append(
                                    {'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})

                            # Insert bottom line
                            rle_list.append(
                                {'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(
                        segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(
                        str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['id']] = polygons_list
            if i < len(self.colors):
                poly_colors[segm['id']] = self.colors[i]
            else:
                poly_colors[segm['id']] = 'white'

            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] +
                           bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['id']] = str(
                bbox_points).lstrip('[').rstrip(']')
            bbox_categories[segm['id']] = self.categories[segm['category_id']]
            # Print details
            print('    {}:{}:{}'.format(
                segm['id'], poly_colors[segm['id']], self.categories[segm['category_id']]))

        # Draw segmentation polygons on image
        html = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(
            image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(
            adjusted_width, adjusted_height)

        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(
                        points, fill_color, stroke_color)

        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(
                        x, y, w, h, fill_color, stroke_color)

        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                x, y = [int(i) for i in points.split()[:2]]
                html += '<text x="{}" y="{}" fill="yellow">{}</text>'.format(
                    x, y, bbox_categories[seg_id]["name"])
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(
                    points, fill_color, stroke_color)

        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html

    def process_info(self):
        self.info = self.coco.get('info')

    def process_licenses(self):
        self.licenses = self.coco.get('licenses')

    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['id']
            super_category = category['supercategory']

            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                # Create a new set with the category id
                self.super_categories[super_category] = {cat_id}
            else:
                self.super_categories[super_category] |= {
                    cat_id}  # Add category id to the set

    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image

    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %%
annotation_path = "trainval.json"
image_dir = "images"

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
# Out:
# Dataset Info:
# =============
# Licenses:
# =========
# Categories:
# =========
#   super_category: image
#     id 0: image
#
#   super_category: list
#     id 1: list
#
#   super_category: table
#     id 2: table
#
#   super_category: text
#     id 3: text
#
#   super_category: title
#     id 4: title

# %%
for k, v in coco_dataset.images.items():
    print(k, v)
# Out:
# 0 {'height': 3509, 'width': 2481, 'id': 0, 'file_name': 'image (1).jpg'}
# 1 {'height': 3509, 'width': 2481, 'id': 1, 'file_name': 'image (10).jpg'}
# 2 {'height': 3509, 'width': 2481, 'id': 2, 'file_name': 'image (11).jpg'}
# 3 {'height': 3509, 'width': 2481, 'id': 3, 'file_name': 'image (12).jpg'}
# 4 {'height': 3509, 'width': 2481, 'id': 4, 'file_name': 'image (13).jpg'}
# 5 {'height': 3509, 'width': 2481, 'id': 5, 'file_name': 'image (14).jpg'}
# 6 {'height': 3509, 'width': 2481, 'id': 6, 'file_name': 'image (15).jpg'}
# 7 {'height': 3509, 'width': 2481, 'id': 7, 'file_name': 'image (16).jpg'}
# 8 {'height': 3509, 'width': 2481, 'id': 8, 'file_name': 'image (17).jpg'}
# 9 {'height': 3509, 'width': 2481, 'id': 9, 'file_name': 'image (18).jpg'}
# 10 {'height': 3509, 'width': 2481, 'id': 10, 'file_name': 'image (19).jpg'}
# 11 {'height': 3509, 'width': 2481, 'id': 11, 'file_name': 'image (2).jpg'}
# 12 {'height': 3509, 'width': 2481, 'id': 12, 'file_name': 'image (20).jpg'}
# 13 {'height': 3509, 'width': 2481, 'id': 13, 'file_name': 'image (20).jpg'}
# 14 {'height': 3509, 'width': 2481, 'id': 14, 'file_name': 'image (22).jpg'}
# 15 {'height': 3509, 'width': 2481, 'id': 15, 'file_name': 'image (23).jpg'}
# 16 {'height': 3509, 'width': 2481, 'id': 16, 'file_name': 'image (24).jpg'}
# 17 {'height': 3509, 'width': 2481, 'id': 17, 'file_name': 'image (25).jpg'}
# 18 {'height': 3509, 'width': 2481, 'id': 18, 'file_name': 'image (26).jpg'}
# 19 {'height': 3509, 'width': 2481, 'id': 19, 'file_name': 'image (27).jpg'}
# 20 {'height': 3509, 'width': 2481, 'id': 20, 'file_name': 'image (28).jpg'}
# 21 {'height': 3509, 'width': 2481, 'id': 21, 'file_name': 'image (29).jpg'}
# 22 {'height': 3509, 'width': 2481, 'id': 22, 'file_name': 'image (3).jpg'}
# 23 {'height': 3509, 'width': 2481, 'id': 23, 'file_name': 'image (30).jpg'}
# 24 {'height': 3509, 'width': 2481, 'id': 24, 'file_name': 'image (31).jpg'}
# 25 {'height': 3509, 'width': 2481, 'id': 25, 'file_name': 'image (32).jpg'}
# 26 {'height': 3509, 'width': 2481, 'id': 26, 'file_name': 'image (33).jpg'}
# 27 {'height': 3509, 'width': 2481, 'id': 27, 'file_name': 'image (34).jpg'}
# 28 {'height': 3509, 'width': 2481, 'id': 28, 'file_name': 'image (35).jpg'}
# 29 {'height': 3509, 'width': 2481, 'id': 29, 'file_name': 'image (36).jpg'}
# 30 {'height': 3509, 'width': 2481, 'id': 30, 'file_name': 'image (37).jpg'}
# 31 {'height': 3509, 'width': 2481, 'id': 31, 'file_name': 'image (38).jpg'}
# 32 {'height': 3509, 'width': 2481, 'id': 32, 'file_name': 'image (39).jpg'}
# 33 {'height': 3509, 'width': 2481, 'id': 33, 'file_name': 'image (4).jpg'}
# 34 {'height': 3509, 'width': 2481, 'id': 34, 'file_name': 'image (40).jpg'}
# 35 {'height': 3509, 'width': 2481, 'id': 35, 'file_name': 'image (41).jpg'}
# 36 {'height': 3509, 'width': 2481, 'id': 36, 'file_name': 'image (42).jpg'}
# 37 {'height': 3509, 'width': 2481, 'id': 37, 'file_name': 'image (43).jpg'}
# 38 {'height': 3509, 'width': 2481, 'id': 38, 'file_name': 'image (44).jpg'}
# 39 {'height': 3509, 'width': 2481, 'id': 39, 'file_name': 'image (45).jpg'}
# 40 {'height': 3509, 'width': 2481, 'id': 40, 'file_name': 'image (46).jpg'}
# 41 {'height': 3509, 'width': 2481, 'id': 41, 'file_name': 'image (47).jpg'}
# 42 {'height': 3509, 'width': 2481, 'id': 42, 'file_name': 'image (48).jpg'}
# 43 {'height': 3509, 'width': 2481, 'id': 43, 'file_name': 'image (5).jpg'}
# 44 {'height': 3509, 'width': 2481, 'id': 44, 'file_name': 'image (6).jpg'}
# 45 {'height': 3509, 'width': 2481, 'id': 45, 'file_name': 'image (7).jpg'}
# 46 {'height': 3509, 'width': 2481, 'id': 46, 'file_name': 'image (8).jpg'}
# 47 {'height': 3509, 'width': 2481, 'id': 47, 'file_name': 'image (9).jpg'}
# 48 {'height': 3509, 'width': 2481, 'id': 48, 'file_name': 'image.jpg'}

# %%
html = coco_dataset.display_image(5, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 5
#   file_name: image (14).jpg
#   segmentations (3):
#     22:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     23:purple:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     24:red:{'supercategory': 'list', 'id': 1, 'name': 'list'}
# <div class="container" style="position:relative;"><img src="images/image (14).jpg" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="848.6094316807739"><polygon points="300 759 300 777 314 775 311 759" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points=" 81 120  82 104 284 105 287 123" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points=" 80 146  80 565 527 565 527 143" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><text x="300" y="759" fill="yellow">text</text><polygon points="300 759 313 759 313 777 300 777 300 759" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="81" y="104" fill="yellow">title</text><polygon points=" 81 104 287 104 287 123  81 123  81 104" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="80" y="143" fill="yellow">list</text><polygon points=" 80 143 527 143 527 565  80 565  80 143" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>

# %%
html = coco_dataset.display_image(1, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 1
#   file_name: image (10).jpg
#   segmentations (2):
#     8:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     9:purple:{'supercategory': 'list', 'id': 1, 'name': 'list'}
# <div class="container" style="position:relative;"><img src="images/image (10).jpg" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="848.6094316807739"><polygon points="296 758 295 777 317 777 312 756" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points=" 81 101  80 714 510 720 516 102" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><text x="295" y="756" fill="yellow">text</text><polygon points="295 756 317 756 317 777 295 777 295 756" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="80" y="101" fill="yellow">list</text><polygon points=" 80 101 516 101 516 719  80 719  80 101" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>

# %%
for i in range(0, 15):
    html = coco_dataset.display_image(i, use_url=False)
    IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 0
#   file_name: image (1).jpg
#   segmentations (7):
#     1:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     2:purple:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     3:red:{'supercategory': 'image', 'id': 0, 'name': 'image'}
#     4:green:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     5:orange:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     6:salmon:{'supercategory': 'list', 'id': 1, 'name': 'list'}
#     7:pink:{'supercategory': 'text', 'id': 3, 'name': 'text'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 1
#   file_name: image (10).jpg
#   segmentations (2):
#     8:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     9:purple:{'supercategory': 'list', 'id': 1, 'name': 'list'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 2
#   file_name: image (11).jpg
#   segmentations (2):
#     10:blue:{'supercategory': 'list', 'id': 1, 'name': 'list'}
#     11:purple:{'supercategory': 'text', 'id': 3, 'name': 'text'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 3
#   file_name: image (12).jpg
#   segmentations (8):
#     12:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     13:purple:{'supercategory': 'image', 'id': 0, 'name': 'image'}
#     14:red:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     15:green:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     16:orange:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     17:salmon:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     18:pink:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     19:gold:{'supercategory': 'text', 'id': 3, 'name': 'text'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 4
#   file_name: image (13).jpg
#   segmentations (2):
#     20:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     21:purple:{'supercategory': 'list', 'id': 1, 'name': 'list'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 5
#   file_name: image (14).jpg
#   segmentations (3):
#     22:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     23:purple:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     24:red:{'supercategory': 'list', 'id': 1, 'name': 'list'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 6
#   file_name: image (15).jpg
#   segmentations (3):
#     25:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     26:purple:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     27:red:{'supercategory': 'title', 'id': 4, 'name': 'title'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 7
#   file_name: image (16).jpg
#   segmentations (4):
#     28:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     29:purple:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     30:red:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     31:green:{'supercategory': 'title', 'id': 4, 'name': 'title'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 8
#   file_name: image (17).jpg
#   segmentations (4):
#     32:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     33:purple:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     34:red:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     35:green:{'supercategory': 'title', 'id': 4, 'name': 'title'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 9
#   file_name: image (18).jpg
#   segmentations (4):
#     36:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     37:purple:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     38:red:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     39:green:{'supercategory': 'text', 'id': 3, 'name': 'text'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 10
#   file_name: image (19).jpg
#   segmentations (6):
#     40:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     41:purple:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     42:red:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     43:green:{'supercategory': 'table', 'id': 2, 'name': 'table'}
#     44:orange:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     45:salmon:{'supercategory': 'title', 'id': 4, 'name': 'title'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 11
#   file_name: image (2).jpg
#   segmentations (7):
#     46:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     47:purple:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     48:red:{'supercategory': 'image', 'id': 0, 'name': 'image'}
#     49:green:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     50:orange:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     51:salmon:{'supercategory': 'list', 'id': 1, 'name': 'list'}
#     52:pink:{'supercategory': 'text', 'id': 3, 'name': 'text'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 12
#   file_name: image (20).jpg
#   segmentations (7):
#     53:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     54:purple:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     55:red:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     56:green:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     57:orange:{'supercategory': 'image', 'id': 0, 'name': 'image'}
#     58:salmon:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     59:pink:{'supercategory': 'title', 'id': 4, 'name': 'title'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 13
#   file_name: image (20).jpg
#   segmentations (7):
#     60:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     61:purple:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     62:red:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     63:green:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     64:orange:{'supercategory': 'image', 'id': 0, 'name': 'image'}
#     65:salmon:{'supercategory': 'title', 'id': 4, 'name': 'title'}
#     66:pink:{'supercategory': 'title', 'id': 4, 'name': 'title'}
# Image:
# ======
#   height: 3509
#   width: 2481
#   id: 14
#   file_name: image (22).jpg
#   segmentations (6):
#     67:blue:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     68:purple:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     69:red:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     70:green:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     71:orange:{'supercategory': 'text', 'id': 3, 'name': 'text'}
#     72:salmon:{'supercategory': 'title', 'id': 4, 'name': 'title'}

# %%
IPython.display.HTML(html)
# Out:
# <div class="container" style="position:relative;"><img src="images/image (22).jpg" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="848.6094316807739"><polygon points="117 106 116 131  82 133  82 176 195 174 191 147 529 148 528 104" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="139 213 140 238  82 239  83 474 169 470 168 447 529 446 529 212" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="107 482 108 505  83 507  82 659 271 657 264 634 529 632 527 483" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="108 669 108 699  82 700  83 741 530 742 529 670" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points="297 762 299 775 313 775 312 761" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points=" 83 187  80 200 268 201 269 187" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><text x="81" y="104" fill="yellow">text</text><polygon points=" 81 104 529 104 529 176  81 176  81 104" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="82" y="212" fill="yellow">text</text><polygon points=" 82 212 529 212 529 474  82 474  82 212" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="82" y="482" fill="yellow">text</text><polygon points=" 82 482 529 482 529 659  82 659  82 482" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /><text x="82" y="669" fill="yellow">text</text><polygon points=" 82 669 530 669 530 742  82 742  82 669" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0" /><text x="297" y="761" fill="yellow">text</text><polygon points="297 761 312 761 312 775 297 775 297 761" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0" /><text x="80" y="187" fill="yellow">title</text><polygon points=" 80 187 269 187 269 201  80 201  80 187" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>

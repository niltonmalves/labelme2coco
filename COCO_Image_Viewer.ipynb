# %% [markdown]
# # COCO Image Viewer
# This notebook will allow you to view details about a COCO dataset and preview segmentations on annotated images.
# Learn more about it at: http://cocodataset.org/

# %%
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# %%
# Load the dataset json
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = ['blue', 'purple', 'red', 'green', 'orange', 'salmon', 'pink', 'gold',
                       'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                       'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                       'magenta', 'sienna', 'maroon']

        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()

        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()

    def display_info(self):
        print('Dataset Info:')
        print('=============')
        if self.info is None:
            return
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))

        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

    def display_licenses(self):
        print('Licenses:')
        print('=========')

        if self.licenses is None:
            return
        requirements = [['id', int],
                        ['url', str],
                        ['name', str]]
        for license in self.licenses:
            for key, item in license.items():
                print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(
                        req, str(req_type)))
            print('')
        print('')

    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(
                    cat_id, self.categories[cat_id]['name']))
            print('')

    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))

        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))

        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))

        else:
            # image_path = os.path.join(self.image_dir, image['file_name'])
            image_path = "{}/{}".format(self.image_dir, image['file_name'])
            image = PILImage.open(image_path)

        # Calculate the size and adjusted display size
        max_width = 600
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height

        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        bbox_categories = {}
        print('  segmentations ({}):'.format(
            len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(
                            trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height)
                                      * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})

                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1  # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(
                                    full_lines_to_insert * adjusted_ratio)
                                rle_list.append(
                                    {'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})

                            # Insert bottom line
                            rle_list.append(
                                {'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(
                        segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(
                        str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['id']] = polygons_list
            if i < len(self.colors):
                poly_colors[segm['id']] = self.colors[i]
            else:
                poly_colors[segm['id']] = 'white'

            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] +
                           bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['id']] = str(
                bbox_points).lstrip('[').rstrip(']')
            bbox_categories[segm['id']] = self.categories[segm['category_id']]
            # Print details
            print('    {}:{}:{}'.format(
                segm['id'], poly_colors[segm['id']], self.categories[segm['category_id']]))

        # Draw segmentation polygons on image
        html = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(
            image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(
            adjusted_width, adjusted_height)

        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(
                        points, fill_color, stroke_color)

        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(
                        x, y, w, h, fill_color, stroke_color)

        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                x, y = [int(i) for i in points.split()[:2]]
                html += '<text x="{}" y="{}" fill="yellow">{}</text>'.format(
                    x, y, bbox_categories[seg_id]["name"])
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(
                    points, fill_color, stroke_color)

        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html

    def process_info(self):
        self.info = self.coco.get('info')

    def process_licenses(self):
        self.licenses = self.coco.get('licenses')

    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['id']
            super_category = category['supercategory']

            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                # Create a new set with the category id
                self.super_categories[super_category] = {cat_id}
            else:
                self.super_categories[super_category] |= {
                    cat_id}  # Add category id to the set

    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image

    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %%
annotation_path = "trainval.json"
image_dir = "images"

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
# Out:
# Dataset Info:
# =============
# Licenses:
# =========
# Categories:
# =========
#   super_category: equation
#     id 0: equation
#
#   super_category: image
#     id 1: image
#
#   super_category: legenda
#     id 2: legenda
#
#   super_category: list
#     id 3: list
#
#   super_category: table
#     id 4: table
#
#   super_category: text
#     id 5: text
#
#   super_category: title
#     id 6: title

# %%
for k, v in coco_dataset.images.items():
    print(k, v)
# Out:
# 0 {'height': 3300, 'width': 2550, 'id': 0, 'file_name': '10320151215MONOGRAFIA_0_pag_0.png'}
# 1 {'height': 3300, 'width': 2550, 'id': 1, 'file_name': '10320151215MONOGRAFIA_0_pag_1.png'}
# 2 {'height': 3300, 'width': 2550, 'id': 2, 'file_name': '10320151215MONOGRAFIA_0_pag_10.png'}
# 3 {'height': 3300, 'width': 2550, 'id': 3, 'file_name': '10320151215MONOGRAFIA_0_pag_11.png'}
# 4 {'height': 3300, 'width': 2550, 'id': 4, 'file_name': '10320151215MONOGRAFIA_0_pag_12.png'}
# 5 {'height': 3300, 'width': 2550, 'id': 5, 'file_name': '10320151215MONOGRAFIA_0_pag_13.png'}
# 6 {'height': 3300, 'width': 2550, 'id': 6, 'file_name': '10320151215MONOGRAFIA_0_pag_14.png'}
# 7 {'height': 3300, 'width': 2550, 'id': 7, 'file_name': '10320151215MONOGRAFIA_0_pag_20.png'}
# 8 {'height': 3300, 'width': 2550, 'id': 8, 'file_name': '10320151215MONOGRAFIA_0_pag_21.png'}
# 9 {'height': 3300, 'width': 2550, 'id': 9, 'file_name': '10320151215MONOGRAFIA_0_pag_22.png'}
# 10 {'height': 3300, 'width': 2550, 'id': 10, 'file_name': '10320151215MONOGRAFIA_0_pag_23.png'}
# 11 {'height': 3300, 'width': 2550, 'id': 11, 'file_name': '10320151215MONOGRAFIA_0_pag_24.png'}
# 12 {'height': 3300, 'width': 2550, 'id': 12, 'file_name': '10320151215MONOGRAFIA_0_pag_25.png'}
# 13 {'height': 3300, 'width': 2550, 'id': 13, 'file_name': '10320151215MONOGRAFIA_0_pag_30.png'}
# 14 {'height': 3300, 'width': 2550, 'id': 14, 'file_name': '10320151215MONOGRAFIA_0_pag_33.png'}
# 15 {'height': 3300, 'width': 2550, 'id': 15, 'file_name': '10320151215MONOGRAFIA_0_pag_39.png'}
# 16 {'height': 3300, 'width': 2550, 'id': 16, 'file_name': '10320151215MONOGRAFIA_0_pag_4.png'}
# 17 {'height': 3300, 'width': 2550, 'id': 17, 'file_name': '10320151215MONOGRAFIA_0_pag_40.png'}
# 18 {'height': 3300, 'width': 2550, 'id': 18, 'file_name': '10320151215MONOGRAFIA_0_pag_45.png'}
# 19 {'height': 3300, 'width': 2550, 'id': 19, 'file_name': '10320151215MONOGRAFIA_0_pag_48.png'}
# 20 {'height': 3300, 'width': 2550, 'id': 20, 'file_name': '10320151215MONOGRAFIA_0_pag_52.png'}
# 21 {'height': 3300, 'width': 2550, 'id': 21, 'file_name': '10320151215MONOGRAFIA_0_pag_6.png'}
# 22 {'height': 3300, 'width': 2550, 'id': 22, 'file_name': '10320151215MONOGRAFIA_0_pag_7.png'}
# 23 {'height': 3300, 'width': 2550, 'id': 23, 'file_name': '10320151215MONOGRAFIA_0_pag_8.png'}
# 24 {'height': 3508, 'width': 2481, 'id': 24, 'file_name': '10720121015TESEMSC_0_pag_32.png'}
# 25 {'height': 3508, 'width': 2481, 'id': 25, 'file_name': '10720121015TESEMSC_0_pag_33.png'}
# 26 {'height': 2481, 'width': 3508, 'id': 26, 'file_name': '10720121015TESEMSC_0_pag_34.png'}
# 27 {'height': 3508, 'width': 2481, 'id': 27, 'file_name': '10720121015TESEMSC_0_pag_35.png'}
# 28 {'height': 3508, 'width': 2481, 'id': 28, 'file_name': '10720121015TESEMSC_0_pag_36.png'}
# 29 {'height': 3508, 'width': 2481, 'id': 29, 'file_name': '10720121015TESEMSC_0_pag_59.png'}
# 30 {'height': 3508, 'width': 2481, 'id': 30, 'file_name': '10720121015TESEMSC_0_pag_68.png'}
# 31 {'height': 3508, 'width': 2481, 'id': 31, 'file_name': '10720121015TESEMSC_0_pag_69.png'}
# 32 {'height': 3508, 'width': 2481, 'id': 32, 'file_name': '10720121015TESEMSC_0_pag_7.png'}
# 33 {'height': 3508, 'width': 2481, 'id': 33, 'file_name': '10720121015TESEMSC_0_pag_92.png'}
# 34 {'height': 3508, 'width': 2481, 'id': 34, 'file_name': '10720121015TESEMSC_0_pag_93.png'}
# 35 {'height': 3508, 'width': 2481, 'id': 35, 'file_name': '10920121011TESEMSC_0_pag_1.png'}
# 36 {'height': 3509, 'width': 2480, 'id': 36, 'file_name': '11220141112TESEMSC_0_pag_0.png'}
# 37 {'height': 3509, 'width': 2480, 'id': 37, 'file_name': '11220141112TESEMSC_0_pag_10.png'}
# 38 {'height': 3509, 'width': 2480, 'id': 38, 'file_name': '11220141112TESEMSC_0_pag_16.png'}
# 39 {'height': 3509, 'width': 2480, 'id': 39, 'file_name': '11220141112TESEMSC_0_pag_30.png'}
# 40 {'height': 3509, 'width': 2480, 'id': 40, 'file_name': '11220141112TESEMSC_0_pag_32.png'}
# 41 {'height': 3509, 'width': 2480, 'id': 41, 'file_name': '11220141112TESEMSC_0_pag_37.png'}
# 42 {'height': 3509, 'width': 2480, 'id': 42, 'file_name': '11220141112TESEMSC_0_pag_41.png'}
# 43 {'height': 3509, 'width': 2480, 'id': 43, 'file_name': '11220141112TESEMSC_0_pag_44.png'}
# 44 {'height': 3509, 'width': 2480, 'id': 44, 'file_name': '11220141112TESEMSC_0_pag_5.png'}
# 45 {'height': 3509, 'width': 2480, 'id': 45, 'file_name': '11220141112TESEMSC_0_pag_50.png'}
# 46 {'height': 3509, 'width': 2480, 'id': 46, 'file_name': '11220141112TESEMSC_0_pag_51.png'}
# 47 {'height': 3509, 'width': 2480, 'id': 47, 'file_name': '11220141112TESEMSC_0_pag_61.png'}
# 48 {'height': 3509, 'width': 2480, 'id': 48, 'file_name': '11220141112TESEMSC_0_pag_62.png'}
# 49 {'height': 3509, 'width': 2480, 'id': 49, 'file_name': '11220141112TESEMSC_0_pag_63.png'}
# 50 {'height': 3509, 'width': 2480, 'id': 50, 'file_name': '11220141112TESEMSC_0_pag_64.png'}
# 51 {'height': 3509, 'width': 2480, 'id': 51, 'file_name': '11220141112TESEMSC_0_pag_65.png'}
# 52 {'height': 3509, 'width': 2480, 'id': 52, 'file_name': '11220141112TESEMSC_0_pag_73.png'}
# 53 {'height': 3509, 'width': 2480, 'id': 53, 'file_name': '11220141112TESEMSC_0_pag_74.png'}
# 54 {'height': 3509, 'width': 2480, 'id': 54, 'file_name': '11220141112TESEMSC_0_pag_75.png'}
# 55 {'height': 3509, 'width': 2480, 'id': 55, 'file_name': '11220141112TESEMSC_0_pag_76.png'}
# 56 {'height': 3509, 'width': 2480, 'id': 56, 'file_name': '11220141112TESEMSC_0_pag_81.png'}
# 57 {'height': 3509, 'width': 2480, 'id': 57, 'file_name': '11220141112TESEMSC_0_pag_84.png'}
# 58 {'height': 3509, 'width': 2480, 'id': 58, 'file_name': '11220141112TESEMSC_0_pag_85.png'}
# 59 {'height': 3509, 'width': 2480, 'id': 59, 'file_name': '11220141112TESEMSC_0_pag_9.png'}
# 60 {'height': 3509, 'width': 2480, 'id': 60, 'file_name': '11220141112TESEMSC_0_pag_90.png'}
# 61 {'height': 3509, 'width': 2480, 'id': 61, 'file_name': '11220141112TESEMSC_0_pag_94.png'}
# 62 {'height': 3509, 'width': 2480, 'id': 62, 'file_name': '11220141112TESEMSC_0_pag_95.png'}
# 63 {'height': 3508, 'width': 2481, 'id': 63, 'file_name': '11420121011MONOGRAFIA_0_pag_0.png'}
# 64 {'height': 2481, 'width': 3508, 'id': 64, 'file_name': '11420121011MONOGRAFIA_0_pag_35.png'}
# 65 {'height': 3508, 'width': 2481, 'id': 65, 'file_name': '11420121011MONOGRAFIA_0_pag_36.png'}
# 66 {'height': 3508, 'width': 2481, 'id': 66, 'file_name': '11420121011MONOGRAFIA_0_pag_37.png'}
# 67 {'height': 3508, 'width': 2481, 'id': 67, 'file_name': '11420121011MONOGRAFIA_0_pag_39.png'}
# 68 {'height': 3508, 'width': 2481, 'id': 68, 'file_name': '41520160623TESEMSC_0_pag_38.png'}
# 69 {'height': 3508, 'width': 2481, 'id': 69, 'file_name': '41520160623TESEMSC_0_pag_39.png'}
# 70 {'height': 3508, 'width': 2481, 'id': 70, 'file_name': '41520160623TESEMSC_0_pag_4.png'}
# 71 {'height': 3509, 'width': 2481, 'id': 71, 'file_name': 'image (1).jpg'}
# 72 {'height': 3509, 'width': 2481, 'id': 72, 'file_name': 'image (10).jpg'}
# 73 {'height': 3509, 'width': 2481, 'id': 73, 'file_name': 'image (11).jpg'}
# 74 {'height': 3509, 'width': 2481, 'id': 74, 'file_name': 'image (12).jpg'}
# 75 {'height': 3509, 'width': 2481, 'id': 75, 'file_name': 'image (13).jpg'}
# 76 {'height': 3509, 'width': 2481, 'id': 76, 'file_name': 'image (14).jpg'}
# 77 {'height': 3509, 'width': 2481, 'id': 77, 'file_name': 'image (15).jpg'}
# 78 {'height': 3509, 'width': 2481, 'id': 78, 'file_name': 'image (16).jpg'}
# 79 {'height': 3509, 'width': 2481, 'id': 79, 'file_name': 'image (17).jpg'}
# 80 {'height': 3509, 'width': 2481, 'id': 80, 'file_name': 'image (18).jpg'}
# 81 {'height': 3509, 'width': 2481, 'id': 81, 'file_name': 'image (19).jpg'}
# 82 {'height': 3509, 'width': 2481, 'id': 82, 'file_name': 'image (2).jpg'}
# 83 {'height': 3509, 'width': 2481, 'id': 83, 'file_name': 'image (20).jpg'}
# 84 {'height': 3509, 'width': 2481, 'id': 84, 'file_name': 'image (20).jpg'}
# 85 {'height': 3509, 'width': 2481, 'id': 85, 'file_name': 'image (22).jpg'}
# 86 {'height': 3509, 'width': 2481, 'id': 86, 'file_name': 'image (23).jpg'}
# 87 {'height': 3509, 'width': 2481, 'id': 87, 'file_name': 'image (24).jpg'}
# 88 {'height': 3509, 'width': 2481, 'id': 88, 'file_name': 'image (25).jpg'}
# 89 {'height': 3509, 'width': 2481, 'id': 89, 'file_name': 'image (26).jpg'}
# 90 {'height': 3509, 'width': 2481, 'id': 90, 'file_name': 'image (27).jpg'}
# 91 {'height': 3509, 'width': 2481, 'id': 91, 'file_name': 'image (28).jpg'}
# 92 {'height': 3509, 'width': 2481, 'id': 92, 'file_name': 'image (29).jpg'}
# 93 {'height': 3509, 'width': 2481, 'id': 93, 'file_name': 'image (3).jpg'}
# 94 {'height': 3509, 'width': 2481, 'id': 94, 'file_name': 'image (30).jpg'}
# 95 {'height': 3509, 'width': 2481, 'id': 95, 'file_name': 'image (31).jpg'}
# 96 {'height': 3509, 'width': 2481, 'id': 96, 'file_name': 'image (32).jpg'}
# 97 {'height': 3509, 'width': 2481, 'id': 97, 'file_name': 'image (33).jpg'}
# 98 {'height': 3509, 'width': 2481, 'id': 98, 'file_name': 'image (34).jpg'}
# 99 {'height': 3509, 'width': 2481, 'id': 99, 'file_name': 'image (35).jpg'}
# 100 {'height': 3509, 'width': 2481, 'id': 100, 'file_name': 'image (36).jpg'}
# 101 {'height': 3509, 'width': 2481, 'id': 101, 'file_name': 'image (37).jpg'}
# 102 {'height': 3509, 'width': 2481, 'id': 102, 'file_name': 'image (38).jpg'}
# 103 {'height': 3509, 'width': 2481, 'id': 103, 'file_name': 'image (39).jpg'}
# 104 {'height': 3509, 'width': 2481, 'id': 104, 'file_name': 'image (4).jpg'}
# 105 {'height': 3509, 'width': 2481, 'id': 105, 'file_name': 'image (40).jpg'}
# 106 {'height': 3509, 'width': 2481, 'id': 106, 'file_name': 'image (41).jpg'}
# 107 {'height': 3509, 'width': 2481, 'id': 107, 'file_name': 'image (42).jpg'}
# 108 {'height': 3509, 'width': 2481, 'id': 108, 'file_name': 'image (43).jpg'}
# 109 {'height': 3509, 'width': 2481, 'id': 109, 'file_name': 'image (44).jpg'}
# 110 {'height': 3509, 'width': 2481, 'id': 110, 'file_name': 'image (45).jpg'}
# 111 {'height': 3509, 'width': 2481, 'id': 111, 'file_name': 'image (46).jpg'}
# 112 {'height': 3509, 'width': 2481, 'id': 112, 'file_name': 'image (47).jpg'}
# 113 {'height': 3509, 'width': 2481, 'id': 113, 'file_name': 'image (48).jpg'}
# 114 {'height': 3509, 'width': 2481, 'id': 114, 'file_name': 'image (5).jpg'}
# 115 {'height': 3509, 'width': 2481, 'id': 115, 'file_name': 'image (6).jpg'}
# 116 {'height': 3509, 'width': 2481, 'id': 116, 'file_name': 'image (7).jpg'}
# 117 {'height': 3509, 'width': 2481, 'id': 117, 'file_name': 'image (8).jpg'}
# 118 {'height': 3509, 'width': 2481, 'id': 118, 'file_name': 'image (9).jpg'}
# 119 {'height': 3509, 'width': 2481, 'id': 119, 'file_name': 'image.jpg'}

# %%
html = coco_dataset.display_image(5, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 5
#   file_name: 10320151215MONOGRAFIA_0_pag_13.png
#   segmentations (9):
#     48:blue:{'supercategory': 'list', 'id': 3, 'name': 'list'}
#     49:purple:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     50:red:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     51:green:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     52:orange:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     53:salmon:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     54:pink:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     55:gold:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     56:orchid:{'supercategory': 'text', 'id': 5, 'name': 'text'}
# <div class="container" style="position:relative;"><img src="images/10320151215MONOGRAFIA_0_pag_13.png" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="776.4705882352941"><polygon points=" 97 310 548 674" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points=" 81  82 352  97" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points=" 78 129 546 164" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="115 107 546 126" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points=" 81 168 398 185" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points=" 81 211 546 266" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><polygon points="115 189 545 205" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points=" 80 269 245 285" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0.5" /><polygon points="113 292 346 302" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0.5" /><text x="97" y="310" fill="yellow">list</text><polygon points=" 97 310 548 310 548 674  97 674  97 310" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="80" y="82" fill="yellow">title</text><polygon points=" 80  82 352  82 352  96  80  96  80  82" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="78" y="129" fill="yellow">text</text><polygon points=" 78 129 546 129 546 164  78 164  78 129" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /><text x="115" y="107" fill="yellow">text</text><polygon points="115 107 546 107 546 126 115 126 115 107" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0" /><text x="80" y="168" fill="yellow">text</text><polygon points=" 80 168 398 168 398 185  80 185  80 168" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0" /><text x="80" y="211" fill="yellow">text</text><polygon points=" 80 211 546 211 546 266  80 266  80 211" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0" /><text x="115" y="189" fill="yellow">text</text><polygon points="115 189 545 189 545 205 115 205 115 189" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0" /><text x="80" y="269" fill="yellow">text</text><polygon points=" 80 269 245 269 245 285  80 285  80 269" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0" /><text x="113" y="292" fill="yellow">text</text><polygon points="113 292 346 292 346 302 113 302 113 292" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>

# %%
html = coco_dataset.display_image(1, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 1
#   file_name: 10320151215MONOGRAFIA_0_pag_1.png
#   segmentations (16):
#     11:blue:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     12:purple:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     13:red:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     14:green:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     15:orange:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     16:salmon:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     17:pink:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     18:gold:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     19:orchid:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     20:slateblue:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     21:limegreen:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     22:seagreen:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     23:darkgreen:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     24:olive:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     25:teal:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     26:aquamarine:{'supercategory': 'title', 'id': 6, 'name': 'title'}
# <div class="container" style="position:relative;"><img src="images/10320151215MONOGRAFIA_0_pag_1.png" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="776.4705882352941"><polygon points="309  89 425 144" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="267 157 304 195" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="310 169 375 193" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="285 380 280 403 281 437 275 444 281 452 326 451 324 436 318 434 322 401
#  316 381" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points="155  83 154 144 184 143 185 148 197 144 195 138 296 135 297 111 233 111
#  232  99 217 102 221 108 202 109 204  82" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points="140 236 471 254" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><polygon points=" 93 269 511 283" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0.5" /><polygon points="153 315 459 326" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0.5" /><polygon points=" 83 337 533 354" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0.5" /><polygon points="111 476 514 488" style="fill:slateblue; stroke:slateblue; stroke-width:1; fill-opacity:0.5" /><polygon points=" 93 493 533 504" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="282 510 346 522" style="fill:seagreen; stroke:seagreen; stroke-width:1; fill-opacity:0.5" /><polygon points="211 543 412 556" style="fill:darkgreen; stroke:darkgreen; stroke-width:1; fill-opacity:0.5" /><polygon points="177 617 448 632" style="fill:olive; stroke:olive; stroke-width:1; fill-opacity:0.5" /><polygon points="235 662 393 673" style="fill:teal; stroke:teal; stroke-width:1; fill-opacity:0.5" /><polygon points="283 696 346 706" style="fill:aquamarine; stroke:aquamarine; stroke-width:1; fill-opacity:0.5" /><text x="309" y="89" fill="yellow">image</text><polygon points="309  89 425  89 425 144 309 144 309  89" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="267" y="157" fill="yellow">image</text><polygon points="267 157 304 157 304 195 267 195 267 157" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="310" y="169" fill="yellow">image</text><polygon points="310 169 375 169 375 193 310 193 310 169" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /><text x="274" y="380" fill="yellow">image</text><polygon points="274 380 326 380 326 452 274 452 274 380" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0" /><text x="154" y="82" fill="yellow">image</text><polygon points="154  82 297  82 297 148 154 148 154  82" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0" /><text x="140" y="236" fill="yellow">title</text><polygon points="140 236 471 236 471 254 140 254 140 236" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0" /><text x="93" y="269" fill="yellow">title</text><polygon points=" 93 269 511 269 511 283  93 283  93 269" style="fill:pink; stroke:pink; stroke-width:1; fill-opacity:0" /><text x="153" y="315" fill="yellow">title</text><polygon points="153 315 459 315 459 326 153 326 153 315" style="fill:gold; stroke:gold; stroke-width:1; fill-opacity:0" /><text x="83" y="336" fill="yellow">title</text><polygon points=" 83 336 533 336 533 354  83 354  83 336" style="fill:orchid; stroke:orchid; stroke-width:1; fill-opacity:0" /><text x="111" y="476" fill="yellow">title</text><polygon points="111 476 514 476 514 488 111 488 111 476" style="fill:slateblue; stroke:slateblue; stroke-width:1; fill-opacity:0" /><text x="93" y="492" fill="yellow">title</text><polygon points=" 93 492 533 492 533 504  93 504  93 492" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0" /><text x="282" y="510" fill="yellow">title</text><polygon points="282 510 346 510 346 522 282 522 282 510" style="fill:seagreen; stroke:seagreen; stroke-width:1; fill-opacity:0" /><text x="211" y="543" fill="yellow">title</text><polygon points="211 543 412 543 412 556 211 556 211 543" style="fill:darkgreen; stroke:darkgreen; stroke-width:1; fill-opacity:0" /><text x="176" y="617" fill="yellow">title</text><polygon points="176 617 448 617 448 632 176 632 176 617" style="fill:olive; stroke:olive; stroke-width:1; fill-opacity:0" /><text x="235" y="662" fill="yellow">title</text><polygon points="235 662 393 662 393 673 235 673 235 662" style="fill:teal; stroke:teal; stroke-width:1; fill-opacity:0" /><text x="283" y="696" fill="yellow">title</text><polygon points="283 696 346 696 346 706 283 706 283 ...

# %%
for i in range(0, 15):
    html = coco_dataset.display_image(i, use_url=False)
    IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 0
#   file_name: 10320151215MONOGRAFIA_0_pag_0.png
#   segmentations (10):
#     1:blue:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     2:purple:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     3:red:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     4:green:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     5:orange:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     6:salmon:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     7:pink:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     8:gold:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     9:orchid:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     10:slateblue:{'supercategory': 'title', 'id': 6, 'name': 'title'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 1
#   file_name: 10320151215MONOGRAFIA_0_pag_1.png
#   segmentations (16):
#     11:blue:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     12:purple:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     13:red:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     14:green:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     15:orange:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     16:salmon:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     17:pink:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     18:gold:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     19:orchid:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     20:slateblue:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     21:limegreen:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     22:seagreen:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     23:darkgreen:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     24:olive:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     25:teal:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     26:aquamarine:{'supercategory': 'title', 'id': 6, 'name': 'title'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 2
#   file_name: 10320151215MONOGRAFIA_0_pag_10.png
#   segmentations (2):
#     27:blue:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     28:purple:{'supercategory': 'list', 'id': 3, 'name': 'list'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 3
#   file_name: 10320151215MONOGRAFIA_0_pag_11.png
#   segmentations (2):
#     29:blue:{'supercategory': 'list', 'id': 3, 'name': 'list'}
#     30:purple:{'supercategory': 'title', 'id': 6, 'name': 'title'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 4
#   file_name: 10320151215MONOGRAFIA_0_pag_12.png
#   segmentations (17):
#     31:blue:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     32:purple:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     33:red:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     34:green:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     35:orange:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     36:salmon:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     37:pink:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     38:gold:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     39:orchid:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     40:slateblue:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     41:limegreen:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     42:seagreen:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     43:darkgreen:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     44:olive:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     45:teal:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     46:aquamarine:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     47:steelblue:{'supercategory': 'title', 'id': 6, 'name': 'title'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 5
#   file_name: 10320151215MONOGRAFIA_0_pag_13.png
#   segmentations (9):
#     48:blue:{'supercategory': 'list', 'id': 3, 'name': 'list'}
#     49:purple:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     50:red:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     51:green:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     52:orange:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     53:salmon:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     54:pink:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     55:gold:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     56:orchid:{'supercategory': 'text', 'id': 5, 'name': 'text'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 6
#   file_name: 10320151215MONOGRAFIA_0_pag_14.png
#   segmentations (14):
#     57:blue:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     58:purple:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     59:red:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     60:green:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     61:orange:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     62:salmon:{'supercategory': 'list', 'id': 3, 'name': 'list'}
#     63:pink:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     64:gold:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     65:orchid:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     66:slateblue:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     67:limegreen:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     68:seagreen:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     69:darkgreen:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     70:olive:{'supercategory': 'legenda', 'id': 2, 'name': 'legenda'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 7
#   file_name: 10320151215MONOGRAFIA_0_pag_20.png
#   segmentations (4):
#     71:blue:{'supercategory': 'image', 'id': 1, 'name': 'image'}
#     72:purple:{'supercategory': 'list', 'id': 3, 'name': 'list'}
#     73:red:{'supercategory': 'list', 'id': 3, 'name': 'list'}
#     74:green:{'supercategory': 'legenda', 'id': 2, 'name': 'legenda'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 8
#   file_name: 10320151215MONOGRAFIA_0_pag_21.png
#   segmentations (3):
#     75:blue:{'supercategory': 'list', 'id': 3, 'name': 'list'}
#     76:purple:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     77:red:{'supercategory': 'title', 'id': 6, 'name': 'title'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 9
#   file_name: 10320151215MONOGRAFIA_0_pag_22.png
#   segmentations (10):
#     78:blue:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     79:purple:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     80:red:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     81:green:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     82:orange:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     83:salmon:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     84:pink:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     85:gold:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     86:orchid:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     87:slateblue:{'supercategory': 'list', 'id': 3, 'name': 'list'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 10
#   file_name: 10320151215MONOGRAFIA_0_pag_23.png
#   segmentations (1):
#     88:blue:{'supercategory': 'text', 'id': 5, 'name': 'text'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 11
#   file_name: 10320151215MONOGRAFIA_0_pag_24.png
#   segmentations (19):
#     89:blue:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     90:purple:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     91:red:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     92:green:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     93:orange:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     94:salmon:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     95:pink:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     96:gold:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     97:orchid:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     98:slateblue:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     99:limegreen:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     100:seagreen:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     101:darkgreen:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     102:olive:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     103:teal:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     104:aquamarine:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     105:steelblue:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     106:powderblue:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     107:dodgerblue:{'supercategory': 'text', 'id': 5, 'name': 'text'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 12
#   file_name: 10320151215MONOGRAFIA_0_pag_25.png
#   segmentations (3):
#     108:blue:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     109:purple:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     110:red:{'supercategory': 'list', 'id': 3, 'name': 'list'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 13
#   file_name: 10320151215MONOGRAFIA_0_pag_30.png
#   segmentations (4):
#     111:blue:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     112:purple:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     113:red:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     114:green:{'supercategory': 'title', 'id': 6, 'name': 'title'}
# Image:
# ======
#   height: 3300
#   width: 2550
#   id: 14
#   file_name: 10320151215MONOGRAFIA_0_pag_33.png
#   segmentations (4):
#     115:blue:{'supercategory': 'list', 'id': 3, 'name': 'list'}
#     116:purple:{'supercategory': 'text', 'id': 5, 'name': 'text'}
#     117:red:{'supercategory': 'title', 'id': 6, 'name': 'title'}
#     118:green:{'supercategory': 'title', 'id': 6, 'name': 'title'}

# %%
IPython.display.HTML(html)
# Out:
# <div class="container" style="position:relative;"><img src="images/10320151215MONOGRAFIA_0_pag_33.png" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="776.4705882352941"><polygon points="115 109 481 112 479 134 360 134 367 154 530 157 531 174 377 174 361 211
#  428 218 425 237 532 240 531 257 412 255 403 279 531 279 532 295 410 300
#  399 323 532 321 531 341 165 338 163 364 531 363 533 380 438 381 440 403
#  529 403 532 422 394 422 399 445 322 441 326 462  99 464  97 447 115 447
#  116 418  97 418  97 406 116 405 116 380  94 380  96 360 112 362 113 339
#   94 338  96 325 112 323 110 298  90 299  96 282 116 282 112 255  92 256
#   95 200 115 196 112 170  98 170  94 138 117 136" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="115 513 117 530  74 533  86 589 117 592 115 613  78 614  78 669 434 671
#  432 655 536 653 535 595 136 593 132 568 536 569 533 512" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points=" 79 480 351 498" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points=" 80  82 287 100" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><text x="90" y="109" fill="yellow">list</text><polygon points=" 90 109 532 109 532 464  90 464  90 109" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="74" y="512" fill="yellow">text</text><polygon points=" 74 512 536 512 536 671  74 671  74 512" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="79" y="480" fill="yellow">title</text><polygon points=" 79 480 351 480 351 497  79 497  79 480" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /><text x="80" y="82" fill="yellow">title</text><polygon points=" 80  82 287  82 287 100  80 100  80  82" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>
